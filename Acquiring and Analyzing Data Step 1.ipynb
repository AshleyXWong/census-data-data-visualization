# %%
import pandas as pd
census_data = pd.read_csv('censusdata.txt')
print(census_data.columns.values)
# Out:
# ['caseid' 'dAge' 'dAncstry1' 'dAncstry2' 'iAvail' 'iCitizen' 'iClass'
#  'dDepart' 'iDisabl1' 'iDisabl2' 'iEnglish' 'iFeb55' 'iFertil' 'dHispanic'
#  'dHour89' 'dHours' 'iImmigr' 'dIncome1' 'dIncome2' 'dIncome3' 'dIncome4'
#  'dIncome5' 'dIncome6' 'dIncome7' 'dIncome8' 'dIndustry' 'iKorean'
#  'iLang1' 'iLooking' 'iMarital' 'iMay75880' 'iMeans' 'iMilitary'
#  'iMobility' 'iMobillim' 'dOccup' 'iOthrserv' 'iPerscare' 'dPOB'
#  'dPoverty' 'dPwgt1' 'iRagechld' 'dRearning' 'iRelat1' 'iRelat2'
#  'iRemplpar' 'iRiders' 'iRlabor' 'iRownchld' 'dRpincome' 'iRPOB'
#  'iRrelchld' 'iRspouse' 'iRvetserv' 'iSchool' 'iSept80' 'iSex' 'iSubfam1'
#  'iSubfam2' 'iTmpabsnt' 'dTravtime' 'iVietnam' 'dWeek89' 'iWork89'
#  'iWorklwk' 'iWWII' 'iYearsch' 'iYearwrk' 'dYrsserv']

# %%
census_data.head()
# Out:
#    caseid  dAge  dAncstry1  dAncstry2  iAvail  iCitizen  iClass  dDepart  \
# 0   10000     5          0          1       0         0       5        3
# 1   10001     6          1          1       0         0       7        5
# 2   10002     3          1          2       0         0       7        4
# 3   10003     4          1          2       0         0       1        3
# 4   10004     7          1          1       0         0       0        0
#
#    iDisabl1  iDisabl2    ...     iTmpabsnt  dTravtime  iVietnam  dWeek89  \
# 0         2         2    ...             0          5         0        2
# 1         2         2    ...             0          1         0        2
# 2         2         2    ...             0          2         0        2
# 3         2         2    ...             0          1         0        1
# 4         2         2    ...             3          0         0        0
#
#    iWork89  iWorklwk  iWWII  iYearsch  iYearwrk  dYrsserv
# ...

# %%
census_data.tail()
# Out:
#        caseid  dAge  dAncstry1  dAncstry2  iAvail  iCitizen  iClass  dDepart  \
# 71529   81529     7          1          1       0         0       7        4
# 71530   81530     7          2          1       0         0       0        0
# 71531   81531     1          1          2       0         0       0        0
# 71532   81532     3         11          1       0         0       1        5
# 71533   81533     4         11          1       0         0       1        2
#
#        iDisabl1  iDisabl2    ...     iTmpabsnt  dTravtime  iVietnam  dWeek89  \
# 71529         2         2    ...             0          1         0        2
# 71530         2         2    ...             3          0         0        0
# 71531         0         0    ...             0          0         0        0
# 71532         2         2    ...             0          5         0        0
# 71533         2         2    ...             0          4         0        1
#
# ...

# %%
census_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71534 entries, 0 to 71533
# Data columns (total 69 columns):
# caseid       71534 non-null int64
# dAge         71534 non-null int64
# dAncstry1    71534 non-null int64
# dAncstry2    71534 non-null int64
# iAvail       71534 non-null int64
# iCitizen     71534 non-null int64
# iClass       71534 non-null int64
# dDepart      71534 non-null int64
# iDisabl1     71534 non-null int64
# iDisabl2     71534 non-null int64
# iEnglish     71534 non-null int64
# iFeb55       71534 non-null int64
# iFertil      71534 non-null int64
# dHispanic    71534 non-null int64
# dHour89      71534 non-null int64
# dHours       71534 non-null int64
# iImmigr      71534 non-null int64
# dIncome1     71534 non-null int64
# dIncome2     71534 non-null int64
# dIncome3     71534 non-null int64
# dIncome4     71534 non-null int64
# dIncome5     71534 non-null int64
# dIncome6     71534 non-null int64
# dIncome7     71534 non-null int64
# ...

# %%
census_data.describe()
# Out:
#              caseid          dAge     dAncstry1     dAncstry2        iAvail  \
# count  71534.000000  71534.000000  71534.000000  71534.000000  71534.000000
# mean   45766.500000      3.846786      3.265286      1.577781      0.122264
# std    20650.231415      2.054269      4.019452      1.705002      0.675895
# min    10000.000000      0.000000      0.000000      1.000000      0.000000
# 25%    27883.250000      2.000000      1.000000      1.000000      0.000000
# 50%    45766.500000      4.000000      1.000000      1.000000      0.000000
# 75%    63649.750000      6.000000      3.000000      2.000000      0.000000
# max    81533.000000      7.000000     11.000000     12.000000      4.000000
#
#            iCitizen        iClass       dDepart      iDisabl1      iDisabl2  \
# count  71534.000000  71534.000000  71534.000000  71534.000000  71534.000000
# mean       0.290575      1.228954      1.373417      1.429418      1.463094
# ...

# %%
census_data.columns
# Out:
# Index(['caseid', 'dAge', 'dAncstry1', 'dAncstry2', 'iAvail', 'iCitizen',
#        'iClass', 'dDepart', 'iDisabl1', 'iDisabl2', 'iEnglish', 'iFeb55',
#        'iFertil', 'dHispanic', 'dHour89', 'dHours', 'iImmigr', 'dIncome1',
#        'dIncome2', 'dIncome3', 'dIncome4', 'dIncome5', 'dIncome6', 'dIncome7',
#        'dIncome8', 'dIndustry', 'iKorean', 'iLang1', 'iLooking', 'iMarital',
#        'iMay75880', 'iMeans', 'iMilitary', 'iMobility', 'iMobillim', 'dOccup',
#        'iOthrserv', 'iPerscare', 'dPOB', 'dPoverty', 'dPwgt1', 'iRagechld',
#        'dRearning', 'iRelat1', 'iRelat2', 'iRemplpar', 'iRiders', 'iRlabor',
#        'iRownchld', 'dRpincome', 'iRPOB', 'iRrelchld', 'iRspouse', 'iRvetserv',
#        'iSchool', 'iSept80', 'iSex', 'iSubfam1', 'iSubfam2', 'iTmpabsnt',
#        'dTravtime', 'iVietnam', 'dWeek89', 'iWork89', 'iWorklwk', 'iWWII',
#        'iYearsch', 'iYearwrk', 'dYrsserv'],
#       dtype='object')

# %%
len(census_data.index)
# Out:
# 71534

# %%
len(census_data.columns)
# Out:
# 69
